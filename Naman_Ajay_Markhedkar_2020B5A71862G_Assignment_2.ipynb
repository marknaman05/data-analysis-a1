# %%
pip install pandas openpyxl

# %%
import pandas as pd

file_path = '/content/200 participant collected data.xlsx'

# Read the Excel file
df=pd.read_excel("200 participant collected data.xlsx", usecols="B,E")
df
# Out:
#      Gender  Height (cm) (average of 3 measurments)
# 0      Male                              174.000000
# 1      Male                              202.000000
# 2      Male                              182.333333
# 3      Male                              184.000000
# 4      Male                              180.666667
# ..      ...                                     ...
# 195  Female                              164.000000
# 196    Male                              172.000000
# 197    Male                              174.000000
# 198    Male                              174.666667
# 199  Female                              165.000000
#
# [200 rows x 2 columns]

# %%
df1=df.rename(columns={"Height (cm) (average of 3 measurments)":"Height"})
df1
# Out:
#      Gender      Height
# 0      Male  174.000000
# 1      Male  202.000000
# 2      Male  182.333333
# 3      Male  184.000000
# 4      Male  180.666667
# ..      ...         ...
# 195  Female  164.000000
# 196    Male  172.000000
# 197    Male  174.000000
# 198    Male  174.666667
# 199  Female  165.000000
#
# [200 rows x 2 columns]

# %% [markdown]
# # Data Cleaning

# %%
gender_counts = df['Gender'].value_counts()

# Access the count for 'Male' and 'Female'
male_count = gender_counts.get('Male', 0)
female_count = gender_counts.get('Female', 0)

print(f"Number of Males: {male_count}")
print(f"Number of Females: {female_count}")
# Out:
# Number of Males: 113
# Number of Females: 83

# %%
df['Gender']=df['Gender'].str.capitalize()

# %%
# Count no of Males in Gender column

gender_counts = df['Gender'].value_counts()

# Access the count for 'Male' and 'Female'
male_count = gender_counts.get('Male', 0)
female_count = gender_counts.get('Female', 0)

print(f"Number of Males: {male_count}")
print(f"Number of Females: {female_count}")
# Out:
# Number of Males: 117
# Number of Females: 83

# %% [markdown]
# # Data Visualization

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create a figure with subplots
fig, axes = plt.subplots(3, 1, figsize=(8, 15))

# Histogram plot
sns.histplot(data=df, x='Height (cm) (average of 3 measurments)', hue='Gender', kde=True, ax=axes[0])
axes[0].set_title('Histogram')

# Box plot
sns.boxplot(data=df, x='Height (cm) (average of 3 measurments)', y='Gender', ax=axes[1])
axes[1].set_title('Box Plot')

# Violin plot
sns.violinplot(data=df, x='Height (cm) (average of 3 measurments)', y='Gender', ax=axes[2])
axes[2].set_title('Violin Plot')

plt.tight_layout()
plt.show()
